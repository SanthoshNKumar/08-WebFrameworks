# %%
'''
Steps

Step 1 : Install Django 
    - pip install Django

Step 2 : Create 'Django Project'
    - django-admin startproject DiabetesPrediction

Step 3 : Open the Newly Created Django Project From Spyder IDE
    - Projects->New Project->Existing Directory->Location->DiabetesPrediction(Folder)

Step 4 : Create templates folder and add home.html file

Step 6 : Add new py file (views.py)

Step 7 : Goto urls.py file add url patterns 'path("", views.home),'

Step 8 : Goto settings.py file add templates items : 'DIRS': [os.path.join(BASE_DIR,'templates')]

Step 9 : create defination or method in views.py file which renders to the home.html file

# %% [markdown]
# # 01 Create Django Project

# %% [markdown]
# ![#01%20Create%20Django%20Project.png](attachment:#01%20Create%20Django%20Project.png)

# %% [markdown]
# # 02 Open Django Project on Spyder

# %% [markdown]
# ![#02.1%20Open%20Django%20Project%20on%20Spyder.PNG](attachment:#02.1%20Open%20Django%20Project%20on%20Spyder.PNG)

# %% [markdown]
# ![#02.2%20Open%20Django%20Project%20on%20Spyder.PNG](attachment:#02.2%20Open%20Django%20Project%20on%20Spyder.PNG)

# %% [markdown]
# ![#02.3%20Open%20Django%20Project%20on%20Spyder.PNG](attachment:#02.3%20Open%20Django%20Project%20on%20Spyder.PNG)

# %% [markdown]
# ![#03.4%20Create%20Django%20Web%20App.PNG](attachment:#03.4%20Create%20Django%20Web%20App.PNG)

# %% [markdown]
# # 03 Create Django Web App

# %% [markdown]
# ![#03.1%20Create%20Django%20Web%20App.PNG](attachment:#03.1%20Create%20Django%20Web%20App.PNG)

# %% [markdown]
# ![#03.2%20Create%20Django%20Web%20App.PNG](attachment:#03.2%20Create%20Django%20Web%20App.PNG)

# %% [markdown]
# ![#03.3%20Create%20Django%20Web%20App.PNG](attachment:#03.3%20Create%20Django%20Web%20App.PNG)

# %% [markdown]
# ![#03.4%20Create%20Django%20Web%20App.PNG](attachment:#03.4%20Create%20Django%20Web%20App.PNG)

# %% [markdown]
# ![#03.5%20Create%20Django%20Web%20App.PNG](attachment:#03.5%20Create%20Django%20Web%20App.PNG)

# %% [markdown]
# ![#03.6%20Create%20Django%20Web%20App.PNG](attachment:#03.6%20Create%20Django%20Web%20App.PNG)

# %% [markdown]
# ![#03.7%20Create%20Django%20Web%20App.PNG](attachment:#03.7%20Create%20Django%20Web%20App.PNG)

# %% [markdown]
# # 04 Run Django Project

# %% [markdown]
# ![#04%20Run%20Django%20Project.png](attachment:#04%20Run%20Django%20Project.png)
