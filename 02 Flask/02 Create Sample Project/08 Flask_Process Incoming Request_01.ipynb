# %% [markdown]
# ![Flask_Process%20Incoming%20Request_01.png](attachment:Flask_Process%20Incoming%20Request_01.png)

# %% [markdown]
# ![Flask_Process%20Incoming%20Request_02.png](attachment:Flask_Process%20Incoming%20Request_02.png)
